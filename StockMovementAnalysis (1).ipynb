# %%
pip install telethon
# Out:
# Collecting telethon
#   Downloading Telethon-1.38.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting pyaes (from telethon)
#   Downloading pyaes-1.6.1.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/dist-packages (from telethon) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa->telethon) (0.6.1)
# Downloading Telethon-1.38.1-py3-none-any.whl (702 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.2/702.2 kB 16.9 MB/s eta 0:00:00
# Building wheels for collected packages: pyaes
#   Building wheel for pyaes (setup.py) ... done
#   Created wheel for pyaes: filename=pyaes-1.6.1-py3-none-any.whl size=26346 sha256=0778e7526f3905a707cad884fd2d44b3e8798be0c8d70147791f435095bd6fab
#   Stored in directory: /root/.cache/pip/wheels/d6/84/5f/ea6aef85a93c7e1922486369874f4740a5642d261e09c59140
# Successfully built pyaes
# Installing collected packages: pyaes, telethon
# Successfully installed pyaes-1.6.1 telethon-1.38.1

# %%
# !pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)

# %%
import nest_asyncio
from telethon import TelegramClient
import asyncio
import os

# Apply nest_asyncio to allow nested event loops
nest_asyncio.apply()

# Replace with your values
api_id = '24784796'
api_hash = 'c3b056cb039b706a1284973a3bf42435'
group_or_channel = '@STOCKGAINERSS'

# Define session file name
session_file = 'my_session.session'

async def fetch_messages():
    # Use an async context manager
    async with TelegramClient(session_file, api_id, api_hash) as client:
        # Fetch messages asynchronously
        messages = await client.get_messages(group_or_channel, limit=100)

        # Process and print messages
        for message in messages:
            print(f"Date: {message.date}, Content: {message.text}")

# Call the async function using `await` in Colab
await fetch_messages()
# Out:
# Date: 2024-12-06 14:37:28+00:00, Content: **Stock Gainers (SEBI REGISTERED)
# ****⭐️****Live Analysis of 6th DEC
#
# 1. OPTION ANALYSIS
#
# CHAMBAL FERTILIZER 450CE 19 TO 24****🔥****
# CESE 8.8 TO 10
# ZOMATO 300CE 10.7 TO 12.5****🔥****
# PAYTM 980CE 30 TO 40****🔥****
# PAYTM 1000CE 35 TO 40****🔥****
# VEDANTA 500CE 15.5 TO 17.5****🔥****
#
#
# 2. STOCK FUTURE & EQUITY CASH ANALYSIS
#
# DBEIL  190 TO 197****🔥****
# ARKA DEVELOPERS 176 TO 181
# VIMTALAB 960 TO 945****➖****
#
#
#
#
# Note: Those who are tracking our Live Analysis please read our disclaimer.
#
# Focus On the Right Analysis
#
#    FOR PRIME  MEMBERSHIP
#            PING ****@SG005****✔️**
# Date: 2024-12-06 09:47:38+00:00, Content: Bullish On
# Angel ONE via Option
# Date: 2024-12-06 09:45:09+00:00, Content: ANGEL ONE
# Date: 2024-12-06 09:44:19+00:00, Content: ANGEL ONE
# Date: 2024-12-06 09:44:15+00:00, Content: ONE STOCK READY FOR DECENT BREAKOUT
# Date: 2024-12-06 09:29:57+00:00, Content: Deepak Builders
#
# Towards day High
#
# Keep riding this
# Date: 2024-12-06 09:29:21+00:00, Content: ZOMATO
#
# 300CE
#
# 10.7 to 12.5 🔥
#
# Trail support 10.7
# Date: 2024-12-06 09:28:39+00:00, Content: Bank Of Baroda
#
# Ready for breakout
# Date: 2024-12-06 09:21:43+00:00, Content: 17.5 🔥
# Date: 2024-12-06 08:49:11+00:00, Content: POSITIONAL OPTION BUYING
#
# VEDANTA 500CE
#
# CMP 15.5
#
# Support 12
#
# Expected 18-22-27
#
#
# **Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-06 08:32:08+00:00, Content: ALL ABOVE FEEDBACKS ARE NOT JUST RESULT OF OUR HARD WORK
#
# BUT SHOWS PASSION OF PRIME TRADERS AND THEIR DISCIPLINE TRADING.
#
# LOVE YOU ALL
# Let's meet on Monday
# we still have 3 weeks this year ✅✅✅✅
#
# Have a great weekend!🎉
# Date: 2024-12-06 08:29:23+00:00, Content:
# Date: 2024-12-06 08:27:17+00:00, Content: TO BE PART OF
# PRIME GROUP
# , PING @SG005 ✅✅👍
# Date: 2024-12-06 08:25:51+00:00, Content:
# Date: 2024-12-06 08:25:09+00:00, Content:
# Date: 2024-12-06 08:24:52+00:00, Content:
# Date: 2024-12-06 08:23:51+00:00, Content: `WE ARE ENDIND WEEK` JUST LIKE EVERY OTHER TRADER
#
# BUT IT WAS A BIT DIFFERENT FOR STOCK GAINERS PRIME TRADERS 🥰🥰🥰😎
# Date: 2024-12-06 06:59:32+00:00, Content: TO JOIN PRIME, Ping @SG005 ✅✅
# Date: 2024-12-06 06:59:11+00:00, Content: WHAT A Aag 🔥🔥🔥🔥❤️
#
# CONGRATULATIONS ON FANTASTIC WEEK 👏 🙌
# Date: 2024-12-06 06:54:59+00:00, Content: PAYTM
#
# Again 🔥
#
# 40 🔥
# Date: 2024-12-06 06:50:06+00:00, Content: MCX
# Towards buyers
# Circuit
# Date: 2024-12-06 06:48:40+00:00, Content: Look
#
# PAYTM 🔥
#
# NOW
# Date: 2024-12-06 06:47:40+00:00, Content: AGAIN
# POSITIONAL View
#
# PAYTM 1000CE
#
# CMP 35-37
#
# Support 25
#
# Expected 50-60+
#
#
# **Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-06 06:39:40+00:00, Content: Option Buying
#
# Paytm 980CE
#
# 30 to 40 🔥
#
# View achieved
# Date: 2024-12-06 06:39:23+00:00, Content: Paytm 🔥
# Date: 2024-12-06 06:36:09+00:00, Content: Paytm
#
# Biggest Resistance 1000-1010
# Date: 2024-12-06 06:35:13+00:00, Content: PAYTM 🔥
#
# 980CE 🔥
# Date: 2024-12-06 06:34:53+00:00, Content: PAYTM 🔥
# Date: 2024-12-06 05:49:03+00:00, Content: HBL Power System
#
#  View shared to prime Members
# Date: 2024-12-06 05:48:41+00:00, Content: HBL Power System
# Date: 2024-12-06 05:40:59+00:00, Content: ZOMATO
# Date: 2024-12-06 05:40:57+00:00, Content: 12.7 🔥
# Date: 2024-12-06 05:35:41+00:00, Content: 12.3
# Date: 2024-12-06 05:33:25+00:00, Content: ZOMATO
# 10.7 to 11.9 🔥
#
# Keep riding this
# Date: 2024-12-06 05:25:56+00:00, Content: Expected 307-310
# ZOMATO
# Date: 2024-12-06 05:25:34+00:00, Content: ZOMATO sharply recovered
# Date: 2024-12-06 05:25:23+00:00, Content: **OPTION BUYING VIEW
#
# TILL TOMORROW
#
# ZOMATO 300CE
#
# CMP 10.7
#
# Support only 10
#
# Expected 13-15++
#
#
# Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-06 05:11:48+00:00, Content: LOOK CESC
# Volumes
#
# Closing above 210
#
# Stock can test 225-235
# Date: 2024-12-06 05:11:06+00:00, Content: **POSITIONAL OPTION BUYING
#
#  CESC 200CE
#
# CMP 8.8
#
# Support 5
#
# Expected view 11-13-18+
#
#
# Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-06 05:09:15+00:00, Content: CESC
#
# REC
# PFC
#
# WATCH
# Date: 2024-12-06 04:58:06+00:00, Content: EQUITY PICK
#
# VIMTA LAB
#
# CMP 960-965
#
# SUPPORT 945
#
# EXPECTED 985-1010
#
#
# **Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-06 04:52:33+00:00, Content: Mothersonsumi
# Date: 2024-12-06 04:19:34+00:00, Content: Bullish On
#
# Adani Green 🔥
# Date: 2024-12-06 04:19:24+00:00, Content: Stock Option
#
# Chambal Fertilizer
#
# 540CE
#
# 19 to 24
#
# View achieved
# Date: 2024-12-06 04:13:15+00:00, Content: ARKA
#
# DECENT MOVE EXPECTED ABOVE 180+
# Date: 2024-12-06 04:12:31+00:00, Content: Another
#
# IPO BASE BREAKOUT
#
# Arka devlopers
#
# CMP 176
#
# Support only 170
#
# Expected 190-210++
#
#
# **Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-06 04:11:56+00:00, Content: DBEIL
#
# 190 to 197 🔥
#
# Keep riding
# Date: 2024-12-06 04:11:46+00:00, Content:
# Date: 2024-12-06 03:54:39+00:00, Content: CHAMBAL FERTILIZER
#
# 🔥 🔥
# Date: 2024-12-06 03:51:29+00:00, Content: DEEPAK BUILDERS
#
# 🔥 🔥
# Date: 2024-12-06 03:50:13+00:00, Content: CHART SOON
# Date: 2024-12-06 03:49:55+00:00, Content: One GOOD Setup
# Date: 2024-12-06 03:49:50+00:00, Content: EQUITY PICK
#
#
# DEEPAK BUILDERS
#
# DBEIL
#
# CMP 190
#
# SUPPORT 175
#
# EXPECTED 210-220+
#
#
# **Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-06 03:49:16+00:00, Content: IPO BASE BREAKOUT SOON
# Date: 2024-12-06 02:03:46+00:00, Content: 🙏 GOOD MORNING ALL 🌻
#
# 🌺 Have A Profitable Day today 🌹
#
#
# NOTE: POSTS HERE ARE BASED ON MY RESEARCH AND ARE FOR EDUCATIONAL PURPOSES ONLY. We are not liable for any Profit or Loss.
#
# PLEASE CONSULT YOUR FINANCIAL ADVISOR
# BEFORE BUYING OR SELLING.
# THANKS! ✨
#
# Few useful Abbreviations for new traders:
# SL: Stop Loss
# TGT: Target
# CMP: Current Market PRICE
# BTST: Buy Today Sell Tomorrow
# STBT: Sell Today Buy Tomorrow
#
# The profit/loss figures mentioned are indicative and based on assumptions.
#
# Futures: Single Lot
# OPTIONS: Single lot
# Index: 4-5lots
# Date: 2024-12-05 14:41:13+00:00, Content: Option Buying
# Date: 2024-12-05 14:34:06+00:00, Content: TOMM PICK
#
# CHAMBAL FERTILIZER
#
# TODAY HIGH WILL BE IMPORTANT
# Date: 2024-12-05 14:31:48+00:00, Content: **Equity Pick
#
# ECLERX SERVICES
#
# 3480 to 3600 🔥
#
# View achieved achieved**
# Date: 2024-12-05 14:30:35+00:00, Content: **Equity Pick
#
# Anup Engineering
#
# 3570 to 3800 🔥
#
# View achieved**
# Date: 2024-12-05 14:30:01+00:00, Content: IPO BASE BREAKOUT
#
# Tolins Tyres
#
# 228 to 255 🔥
#
# View already achieved
# Date: 2024-12-05 14:29:22+00:00, Content: **IPO BASE BREAKOUT
#
# MANBA FIN
#
# 161 to 195 🔥
#
# View achieved
#
# 🔥**
# Date: 2024-12-05 13:09:14+00:00, Content: **Stock Gainers (SEBI REGISTERED)
# ****⭐️****Live Analysis of 5th DEC
#
# 1. OPTION ANALYSIS
#
# CHAMBAL FERTILIZER 540CE  19 TO 21.35
# PAYTM 900CE 68 TO 77****🔥****
# PAYTM 980CE 30 TO 38****🔥****
#
#
#
#
# Note: Those who are tracking our Live Analysis please read our disclaimer.
#
# Focus On the Right Analysis
#
#    FOR PRIME  MEMBERSHIP
#            PING ****@SG005****✔️**
# Date: 2024-12-05 10:17:56+00:00, Content: TO JOIN PRIME, PING @SG005 ❤️
# Date: 2024-12-05 10:17:37+00:00, Content: **SUCH FEEDBACKS AT DAY END** ❤️❤️❤️❤️❤️
# Date: 2024-12-05 10:16:21+00:00, Content: **STOCK GAINERS  >= PUSHPA 2 **♥️
# Date: 2024-12-05 09:53:11+00:00, Content: CHAMBAL FERTILIZER
#
# 🔥 🔥
#
# BIGGEST RESISTANCE 550*552
# Date: 2024-12-05 09:48:05+00:00, Content: CHAMBAL FERTILIZER
#
# Towards Good Closing
# Date: 2024-12-05 07:42:13+00:00, Content: PING @SG005 TO JOIN PRIME 💚✔️✔️✔️
# Date: 2024-12-05 06:27:50+00:00, Content: Paytm
#
# 32 to 38
# Date: 2024-12-05 05:05:20+00:00, Content: Paytm
# Above 1000
#
# Big breakout
# Date: 2024-12-05 05:05:06+00:00, Content: OPTION BUYING
#
# PAYTM 980CE
#
# CMP 30-32
#
# SUPPORT 23
# EXPECTED 40-50+
#
#
# **Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-05 04:59:44+00:00, Content: Option Buying
#
# Paytm 900CE
#
# 68 to 77 🔥
#
# View achieved
# Date: 2024-12-05 04:58:14+00:00, Content: Enjoy
# Date: 2024-12-05 04:58:12+00:00, Content: 77 🔥
# Date: 2024-12-05 04:53:59+00:00, Content: 74 🔥
# Date: 2024-12-05 04:53:56+00:00, Content: Paytm 🔥🔥🔥
# Date: 2024-12-05 04:48:25+00:00, Content: OPTION BUYING
#
# PAYTM 900CE
#
# CMP 68-69
#
# SUPPORT 60
# EXPECTED 77-87
#
#
# **Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-05 04:24:24+00:00, Content: WAARE ENERGIES
# Date: 2024-12-05 04:18:02+00:00, Content: **TO JOIN PRIME GROUP**, PING @SG005 ⭐🛫
# Date: 2024-12-05 04:08:08+00:00, Content: 🔥🔥
#
# CHAMBAL FERTILIZER
# Date: 2024-12-05 03:58:44+00:00, Content: Excellent chart
#
# Chambal Fertilizer
#
# Resistance 550
#
# Above 550 🔥
# Date: 2024-12-05 03:57:39+00:00, Content: **STOCK OPTION
#
# CHAMBAL FERTILIZER 540CE
#
# CMP 19+
#
# SUPPORT 16
#
# EXPECTED 23-25-27++**
# Date: 2024-12-05 03:56:26+00:00, Content: Ready for big breakout
# Date: 2024-12-05 03:56:19+00:00, Content: Soon
# Date: 2024-12-05 03:56:16+00:00, Content: STOCK OPTION
#
# SOOB
# Date: 2024-12-05 01:07:29+00:00, Content: 🙏 GOOD MORNING ALL 🌻
#
# 🌺 Have A Profitable Day today 🌹
#
#
# NOTE: POSTS HERE ARE BASED ON MY RESEARCH AND ARE FOR EDUCATIONAL PURPOSES ONLY. We are not liable for any Profit or Loss.
#
# PLEASE CONSULT YOUR FINANCIAL ADVISOR
# BEFORE BUYING OR SELLING.
# THANKS! ✨
#
# Few useful Abbreviations for new traders:
# SL: Stop Loss
# TGT: Target
# CMP: Current Market PRICE
# BTST: Buy Today Sell Tomorrow
# STBT: Sell Today Buy Tomorrow
#
# The profit/loss figures mentioned are indicative and based on assumptions.
#
# Futures: Single Lot
# OPTIONS: Single lot
# Index: 4-5lots
# Date: 2024-12-04 12:30:39+00:00, Content: **Stock Gainers (SEBI REGISTERED)
# ****⭐️****Live Analysis of 4th DEC
#
#
# 1. STOCK FUTURE & EQUITY CASH ANALYSIS
#
# ANUP ENGINEERING  3400 TO 3690****🔥****
# SIYARAM SILK 860 TO 875
#
#
#
#
# Note: Those who are tracking our Live Analysis please read our disclaimer.
#
# Focus On the Right Analysis
#
#    FOR PRIME  MEMBERSHIP
#            PING ****@SG005****✔️**
# Date: 2024-12-04 09:18:49+00:00, Content: 533
# Date: 2024-12-04 09:13:47+00:00, Content: Equity Pick
#
# BTST
#
# VIEW
#
# SIYARAM SILK
#
# CMP 860-865
#
# SUPPORT 840
#
# EXPECTED 900-930+
#
#
# **Disclaimer :-
# Above calls are Not Buy or Sell Levels,These opinions are for educational purposes only, based on research. Consult your financial advisor before investing.**
# Date: 2024-12-04 09:09:06+00:00, Content: 3690 🔥🔥
# Date: 2024-12-04 08:50:37+00:00, Content: **TO JOIN PRIME GROUP**, `PING` @SG005 ✔️✔️✔️
# Date: 2024-12-04 08:50:28+00:00, Content: THAT IS THE FEEDBACK WE LOVE TO SEE FROM OUR PRIME TRADERS
#
# 🚩🚩🚩
# Date: 2024-12-04 07:38:14+00:00, Content: ZOMATO
# Date: 2024-12-04 07:35:24+00:00, Content: PVR INOX
#
# 🔥 🔥
# Date: 2024-12-04 06:51:35+00:00, Content: Apollotyre breakout above 530
# Date: 2024-12-04 06:11:41+00:00, Content: **PVR INOX
#
#
# STOCK TO WATCH IN LAST 2 HRS**
# Date: 2024-12-04 06:06:54+00:00, Content: TO JOIN PRIME GROUP, PING @SG005 ✔️✔️
# Date: 2024-12-04 06:01:02+00:00, Content: **Three reasons why traders should avoid overtrading**
#
# ✔️**Higher Losses**: `Frequent trades increase risks and transaction costs, reducing profits.`
#
# ✔️**Emotional Stress**: `Overtrading causes burnout, leading to impulsive decisions.`
#
# ✔️**Capital Drain**: `Small losses from frequent trades quickly erode funds.`
#
# MINDSET PLAYS MAJOR ROLE IN STOCK MARKET
# Date: 2024-12-04 05:51:59+00:00, Content: Anup Engineering
#
# 3800 my first Expectation
# Date: 2024-12-04 05:49:47+00:00, Content: 3650 🔥

# %%
import pandas as pd
from telethon import TelegramClient

# Replace with your values
api_id = '24784796'
api_hash = 'c3b056cb039b706a1284973a3bf42435'
group_or_channel = '@STOCKGAINERSS'  # Replace with your correct username or ID
session_file = 'my_session.session'

# Function to fetch messages
async def fetch_messages():
    async with TelegramClient(session_file, api_id, api_hash) as client:
        # Fetch messages
        messages = await client.get_messages(group_or_channel, limit=100)

        # Process the messages into a list of dictionaries
        data = [{"date": msg.date, "text": msg.text} for msg in messages]

        # Convert the list of dictionaries into a DataFrame
        df = pd.DataFrame(data)

        # Save to CSV
        df.to_csv("stock_data.csv", index=False)
        print("Data saved to stock_data.csv")

# Run the fetch_messages function
await fetch_messages()
# Out:
# Data saved to stock_data.csv

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv("stock_data.csv")

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                         date  \
# 0  2024-12-06 14:37:28+00:00
# 1  2024-12-06 09:47:38+00:00
# 2  2024-12-06 09:45:09+00:00
# 3  2024-12-06 09:44:19+00:00
# 4  2024-12-06 09:44:15+00:00
#
#                                                 text
# 0  **Stock Gainers (SEBI REGISTERED)\n****⭐️****L...
# 1                  Bullish On \nAngel ONE via Option
# 2                                          ANGEL ONE
# 3                                          ANGEL ONE
# 4                ONE STOCK READY FOR DECENT BREAKOUT

# %%
from google.colab import files

# Download the file to your local machine
files.download('stock_data.csv')

# %%
def extract_price(text):
    # Ensure the text is a string before attempting to split
    if isinstance(text, str):  # Check if text is a string
        try:
            return float(text.split()[0])  # Attempt to extract the price from the first word
        except (ValueError, IndexError):
            return np.nan  # If extraction fails, return NaN
    return np.nan  # If the text is not a string, return NaN

# %%
# Inspect the unique values or data types in the 'text' column
print(df['text'].dtype)  # Check data type of the 'text' column
print(df['text'].head())  # Preview the first few values
# Out:
# object
# 0    **Stock Gainers (SEBI REGISTERED)\n****⭐️****L...
# 1                    Bullish On \nAngel ONE via Option
# 2                                            ANGEL ONE
# 3                                            ANGEL ONE
# 4                  ONE STOCK READY FOR DECENT BREAKOUT
# Name: text, dtype: object

# %%
# Apply the updated function to create the 'Price' column
df['Price'] = df['text'].apply(extract_price)

# Drop rows with missing prices
df = df.dropna(subset=['Price'])

# Continue with the rest of your process...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load data (assuming 'stock_data.csv' contains stock prices)
df = pd.read_csv("stock_data.csv")

# Check if 'Price' column already exists
if 'Price' not in df.columns:
    # Function to extract price from text, handling non-numeric cases
    def extract_price(text):
        # Check if text is a string and if not, try converting to string
        if not isinstance(text, str):
            text = str(text)
        try:
            # Attempt to split the text and convert the first word to float
            return float(text.split()[0])
        except (ValueError, IndexError):
            # If conversion fails or there's no first word, return NaN
            return np.nan

    # Apply the function to create the 'Price' column
    df['Price'] = df['text'].apply(extract_price)

# Drop rows with missing prices
df = df.dropna()

# Create the target variable - Predict if price goes up or down
df['Price Change'] = np.where(df['Price'].shift(-1) > df['Price'], 1, 0)  # 1 if price goes up, 0 if down

# Features and target
X = df[['Price']]  # You might need to engineer features from 'text'
y = df['Price Change']

# Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize the model
model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            1       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
import yfinance as yf  # For fetching stock data

# Download historical stock data
stock_data = yf.download('AAPL', start='2020-01-01', end='2023-01-01')

# Preprocess the stock data (e.g., create moving averages)
stock_data['5_day_MA'] = stock_data['Close'].rolling(window=5).mean()
stock_data['50_day_MA'] = stock_data['Close'].rolling(window=50).mean()
stock_data['Volume'] = stock_data['Volume']

# Create the target variable (1 if price goes up, 0 if down)
stock_data['Price Change'] = np.where(stock_data['Close'].shift(-1) > stock_data['Close'], 1, 0)

# Drop rows with missing values
stock_data = stock_data.dropna()

# Features and target
X = stock_data[['Close', '5_day_MA', '50_day_MA', 'Volume']]
y = stock_data['Price Change']

# Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build and train the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Accuracy: 0.4859154929577465
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.47      0.47        70
#            1       0.49      0.50      0.50        72
#
#     accuracy                           0.49       142
#    macro avg       0.49      0.49      0.49       142
# weighted avg       0.49      0.49      0.49       142
